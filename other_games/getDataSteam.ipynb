# %%
from steam_key import key
import requests

# %%
id = "76561198001942010"
response = requests.get("https://api.steampowered.com/ISteamUser/GetPlayerSummaries/v0002/?key="+key+"&steamids="+id)
response.json()
# Out:
# {'response': {'players': [{'steamid': '76561198001942010',
#     'communityvisibilitystate': 3,
#     'profilestate': 1,
#     'personaname': 'katiounette',
#     'profileurl': 'https://steamcommunity.com/profiles/76561198001942010/',
#     'avatar': 'https://avatars.akamai.steamstatic.com/40dadc84d23ea8f12d599f2c9a0d9e007bcba9ad.jpg',
#     'avatarmedium': 'https://avatars.akamai.steamstatic.com/40dadc84d23ea8f12d599f2c9a0d9e007bcba9ad_medium.jpg',
#     'avatarfull': 'https://avatars.akamai.steamstatic.com/40dadc84d23ea8f12d599f2c9a0d9e007bcba9ad_full.jpg',
#     'avatarhash': '40dadc84d23ea8f12d599f2c9a0d9e007bcba9ad',
#     'lastlogoff': 1677364639,
#     'personastate': 1,
#     'realname': 'Katia',
#     'primaryclanid': '103582791429521408',
#     'timecreated': 1224321086,
#     'personastateflags': 0}]}}

# %%
requests.get("http://api.steampowered.com/ISteamUser/GetFriendList/v0001/?key="+key+"&steamid="+id+"&relationship=friend").json()
# Out:
# {'friendslist': {'friends': [{'steamid': '76561197965440986',
#     'relationship': 'friend',
#     'friend_since': 1535367833},
#    {'steamid': '76561197969325853',
#     'relationship': 'friend',
#     'friend_since': 0},
#    {'steamid': '76561197979560697',
#     'relationship': 'friend',
#     'friend_since': 1401015826},
#    {'steamid': '76561197991433654',
#     'relationship': 'friend',
#     'friend_since': 1357393742},
#    {'steamid': '76561197998523837',
#     'relationship': 'friend',
#     'friend_since': 1383509337},
#    {'steamid': '76561198017911692',
#     'relationship': 'friend',
#     'friend_since': 1399226070},
#    {'steamid': '76561198024618592',
#     'relationship': 'friend',
#     'friend_since': 1384695653},
#    {'steamid': '76561198028734142',
#     'relationship': 'friend',
#     'friend_since': 1618578755},
#    {'steamid': '76561198035550585',
#     'relationship': 'friend',
#     'friend_since': 1357394440},
#    {'steamid': '76561198038730183',
# ...

# %%
games = requests.get("http://api.steampowered.com/IPlayerService/GetOwnedGames/v0001/?key="+key+"&steamid="+id+"&include_appinfo=true").json()
games
# Out:
# {'response': {'game_count': 61,
#   'games': [{'appid': 70,
#     'name': 'Half-Life',
#     'playtime_forever': 1482,
#     'img_icon_url': '95be6d131fc61f145797317ca437c9765f24b41c',
#     'playtime_windows_forever': 87,
#     'playtime_mac_forever': 0,
#     'playtime_linux_forever': 0,
#     'rtime_last_played': 1652358473},
#    {'appid': 220,
#     'name': 'Half-Life 2',
#     'playtime_forever': 432,
#     'img_icon_url': 'fcfb366051782b8ebf2aa297f3b746395858cb62',
#     'has_community_visible_stats': True,
#     'playtime_windows_forever': 0,
#     'playtime_mac_forever': 0,
#     'playtime_linux_forever': 0,
#     'rtime_last_played': 1497087319},
#    {'appid': 340,
#     'name': 'Half-Life 2: Lost Coast',
#     'playtime_forever': 0,
#     'img_icon_url': '795e85364189511f4990861b578084deef086cb1',
#     'playtime_windows_forever': 0,
#     'playtime_mac_forever': 0,
#     'playtime_linux_forever': 0,
#     'rtime_last_played': 0},
#    {'appid': 240,
# ...

# %%
for g in games['response']['games']:
    print(requests.get("http://api.steampowered.com/ISteamUserStats/GetUserStatsForGame/v0002/?appid="+str(g['appid'])+"&key="+key+"&steamid="+id).json())
# Out:
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
